# %%
from sympy import *

# %%
x, y, z  = symbols('x, y, z')
f = Function('f')(x**3 + 2*x - 1)
f.diff()
# Out:
# (3*x**2 + 2)*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
f = x**3 + 2*x - 1
diff(f, x)
# Out:
# 3*x**2 + 2

# %%
diff(diff(f, x))
# Out:
# 6*x

# %%
diff(f, x)
# Out:
# 3*x**2 + 2

# %%
def f(x):
    return x**3 + 2*x - 1
print('1st derivative : ', diff(f(x), x))
print('2nd derivative : ', diff(f(x), x, 2))
# Out:
# 1st derivative :  3*x**2 + 2
# 2nd derivative :  6*x

# %%
g  = atan(x)
diff(g, x)
# Out:
# 1/(x**2 + 1)

# %%
integrate(diff(g, x))
# Out:
# atan(x)

# %% [markdown]
# ### Exercise:
# * differentiate $\cos(x)$ and $\sin(x)$  and integrate their results

# %%
print(diff(cos(x), x))
integrate(diff(cos(x), x))
# Out:
# -sin(x)
# cos(x)

# %%
print(diff(sin(x), x))
integrate(diff(sin(x), x))
# Out:
# cos(x)
# sin(x)

# %% [markdown]
# ### Exercise:
# * Compute the indefinite integration of the rational expression:
# $$f(x) = \frac{x}{x^3+1}$$

# %%
def h(x):
    return x/(x**3 +1)

# %%
integrate(diff(h(x), x))
# Out:
# x/(x**3 + 1)

# %%
u = exp(2*x)
d = integrate(u, x)
g = diff(d, x)
g
# Out:
# exp(2*x)

# %%
w, a = symbols('w, a')
integrate(x*exp(-a*x)*cos(w*x),(x, 0, oo)).simplify()
# Out:
# Piecewise(((a**2 - w**2)/(a**2 + w**2)**2, Eq(Abs(periodic_argument(polar_lift(w)**2, oo)), 0) & (Abs(periodic_argument(polar_lift(a)**2, oo)) < pi)), (Integral(x*exp(-a*x)*cos(w*x), (x, 0, oo)), True))

# %%
v = symbols('v')
plot(sin(v), (v, 0, pi*2))

# %%
plot(cos(v-3*pi/2)*sin(v), (v, 0, 2*pi))

# %%
plot(2*cos(x) - 2 + 3*sin(2*x), (x, -pi, pi));

# %%
plot(x**2, x**3, x**4-x+1,(x,-10,10)) #ploting multiple f(n) at once

# %%
plot(cos(v-3*pi/2), sin(v), (v, 0, 2*pi))

# %%
plot01 = plot(3*x+2,(x, -100, 100), legend = True, line_color = '#ff9595')

# %%
plot02 = plot((2*x + 12), (x, -100, 100), legend = True)
plot01.extend(plot02)
plot01.show()

# %%
c1 = 2*cos(x)-2+3*sin(2*x)
p1 = plot(cos(x), c1,(x, -pi, pi), legend=True, show=False)
p1[0].line_color= 'b'
p1[1].line_color = '#111111'
p1.show()

# %%
l = [cos(n*x) for n in range (1,4)]

# %%
p3 = plot(*l, (x, 0, 2*pi), show=False, title = '$\cos(nx)$ for n $\in$ [1, 3]', 
          legend=['cos(x)', 'cos(2x)', 'cos(3x)'])
p3[0].line_color = 'r'
p3[1].line_color = 'g'
p3[2].line_color = 'b'
p3.show()

# %%
p = plot(cos(v), sin(v), -sin(v), -cos(v), (v, -pi, pi), legend = True, show = False)
p[0].line_color = '#ffff00'
p[1].line_color = '#00ffff'
p[2].line_color = '#ff00ff'
p[3].line_color = '#ff0000'
p.show()

# %%
plot(cos(v) - 2* sin(v) + cos(v**2), (v, -pi, pi))

# %%
u = symbols('u')
p4 = plotting.plot_parametric(cos(v), sin(v), (v, -pi, pi), xlim=(-3, 3), ylim=(-3,3), line_color='#ff9595')
p4.extend(plot(x**2 -1, show = False))
p4.show()

# %%
a1 = (cos(u), sin(u), (u, 0, 2*pi))
a2 = ((1/3)*cos(u), (1/3)*sin(u), (u, 0, 2*pi))
plotting.plot_parametric(a1, a2)

# %%
plotting.plot3d_parametric_line(cos(u), sin(u), u, (u, -5, 5))

# %%
t = symbols('t')
plotting.plot3d_parametric_surface(cos(u+t), sin(u-t), u-t, (u, 0, 5), (t, 0, 5))

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
 p6 = plot_implicit(y > sqrt(x))

# %%
a1 = (cos(u), sin(u), (u, 0, 2*pi))
a2 = (cos(u)/4, sin(u)/4, (u, 0, 2*pi))
a3 = (- cos(u)/4, sin(u)/4, (u, 0, 2*pi))
plotting.plot_parametric(a1, a2, a3)
